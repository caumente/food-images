# %% [markdown]
# <a href="https://colab.research.google.com/github/caumente/food-images/blob/master/Proyecto_deep_learning_CNN_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.Librerias

# %% [markdown]
# Lo primero que debemos hacer es importar todas las librerías necesarias para llevar a cabo el proyecto. Se ha de destacar que para la correcta ejecución de este notebook, es necesario usar la versión 1.14.0 de tensorflow.
# También es muy interesante configurar el entorno de manera que puedan usarse las GPUs que Google nos proporciona.

# %%
# Si hay algun problema en la ejecución, se deberá desinstalar la versión 2.0.0 de 
# tensorflow e instalar la 1.14.0. y poteriormente reiniciar el entorno de ejecución 
# %tensorflow_version 2.x
# !pip uninstall -y tensorflow
# !pip install tensorflow==1.14.0
# !pip install tensorflow-gpu==1.14.0

import tensorflow as tf
print(tf.__version__)

if tf.test.gpu_device_name():
   print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
   print("Please install GPU version of TF")
# Out:
# Uninstalling tensorflow-2.2.0rc2:
#   Successfully uninstalled tensorflow-2.2.0rc2
# Collecting tensorflow==1.14.0
#   Downloading https://files.pythonhosted.org/packages/de/f0/96fb2e0412ae9692dbf400e5b04432885f677ad6241c088ccc5fe7724d69/tensorflow-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (109.2MB)
#      |████████████████████████████████| 109.2MB 28kB/s
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (0.9.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (1.12.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (0.3.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (1.1.0)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 38.7MB/s
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 41.0MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (1.27.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (0.34.2)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (1.0.8)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (1.12.1)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (1.18.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (3.10.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (0.2.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.14.0) (0.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (3.2.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0) (46.0.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14.0) (2.10.0)
# Installing collected packages: tensorflow-estimator, tensorboard, tensorflow
#   Found existing installation: tensorflow-estimator 2.2.0rc0
#     Uninstalling tensorflow-estimator-2.2.0rc0:
#       Successfully uninstalled tensorflow-estimator-2.2.0rc0
#   Found existing installation: tensorboard 2.2.0
#     Uninstalling tensorboard-2.2.0:
#       Successfully uninstalled tensorboard-2.2.0
# Successfully installed tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0
# Collecting tensorflow-gpu==1.14.0
#   Downloading https://files.pythonhosted.org/packages/76/04/43153bfdfcf6c9a4c38ecdb971ca9a75b9a791bb69a764d652c359aca504/tensorflow_gpu-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (377.0MB)
#      |████████████████████████████████| 377.0MB 42kB/s
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.14.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.18.2)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.3.3)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.2.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.0.8)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.34.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.9.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.12.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.1.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (0.8.1)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.14.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (3.10.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow-gpu==1.14.0) (1.27.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow-gpu==1.14.0) (2.10.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (46.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (3.2.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow-gpu==1.14.0) (1.0.1)
# Installing collected packages: tensorflow-gpu
# Successfully installed tensorflow-gpu-1.14.0
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# 1.14.0
# Default GPU Device: /device:GPU:0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import image
from matplotlib.pyplot import imshow
from datetime import datetime
from google.colab import drive

from sklearn.model_selection import train_test_split
from keras import backend as K
from keras import optimizers
from keras import applications
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, GlobalAveragePooling2D
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 2.Funciones generales

# %% [markdown]
# A lo largo del proyecto, la métrica que vamos a usar para cuantificar si somos capaces de superar el baseline impuesto (4.8) es la raíz del error cuadrático medio. Por tanto, definiremos ahora una función y la reutilizaremos en repetidas ocasiones.
#
# También vamos a definir otra función con la que graficaremos la evolución del error cometido tanto para el conjunto de entrenamiento como para el de validación.

# %%
# RMSE
def root_mean_squared_error(y_true, y_pred):
    return K.sqrt(K.mean(K.square(y_pred - y_true)))

# Plot history
def plot_history(history):
    plt.figure(figsize=(10,5))
    plt.xlabel('Epoch')
    plt.ylabel('RMSE')
    plt.plot(history.epoch, 
             np.array(history.history['root_mean_squared_error']),
             label='Train Loss')
    plt.plot(history.epoch, 
             np.array(history.history['val_root_mean_squared_error']),
             label='Validation Loss')
    plt.legend()
    plt.show()

# %% [markdown]
# # 3.Preparación de los datos

# %% [markdown]
# En este ejercicio vamos a utilizar un conjunto de datos denominado **UNIMIB2016** que está compuesto por 1027 imágenes que contienen platos de comida. Se trata de imágenes en color, con dimensiones espaciales 640 × 480 y cuya etiqueta se corresponde con el porcentaje de píxeles que hacen referencia a la comida dentro de la imagen.
#
# Montamos el Google Drive en el directorio del proyecto y descomprimios el fichero con los datos.

# %%
#drive.mount('/content/gdrive')
# !unzip -n '/content/DL_UNIMIB2016.zip' >> /dev/null

# %% [markdown]
# Definimos las rutas donde hemos situado los datos

# %%
# Paths
data_path = 'UNIMIB2016/'
imgs_path = data_path + "images/"
labels_path = data_path + "percentage.csv"

# %% [markdown]
# ## 3.1. Exploración y preparación del conjunto de etiquetas

# %% [markdown]
# Cargamos el fichero de etiquetas y hacemos un análisis exploratorio rápido para ver que es lo que contiene dicho archivo.
#
# En primer lugar, mostramos la cabecera de los datos para ver que efectivamente contamos con dos columnas, una que nos indica el nombre de la imagen y otra el porcentaje de píxeles que ocupa la comida dentro de la imagen. Además, no está de más comprobar que no tengamos porcentajes inferiores al 0% o superiores al 100%, ya que de ser así, tendríamos que desechar dichos registros por ser anómalos.
#
# La mejor forma de ver esto rápidamente es mediante el uso de un histograma.

# %%
labels = pd.read_csv(labels_path)

print("\nNumber of rows: {}".format(labels.shape[0]))
print("Number of columns: {}\n".format(labels.shape[1]))

labels.head(5)
# Out:
# Number of rows: 1027
# Number of columns: 2
#             image_name  food_pixels
# 0  20151127_114556.jpg     8.847947
# 1  20151127_114946.jpg    20.754738
# 2  20151127_115133.jpg    13.383787
# 3  20151127_115151.jpg    16.034561
# 4  20151127_115229.jpg    17.368320

# %%
# Plot histogram
plt.figure(figsize=(12,6))
plt.hist(labels.food_pixels, bins=50, color='salmon', edgecolor = 'black')
plt.ylabel("Count")
plt.xlabel("Percentage of pixels")
plt.title("Histogram of class label")
plt.show()

# %% [markdown]
# ## 3.2. Exploración y preparación de de imágenes

# %% [markdown]
# Tras haber visto que los datos contenidos en el fichero de etiquetas, a priori son correctos, veamos ahora alguna de las imágenes.

# %%
# Load image
image_num = 10
data = image.imread("./UNIMIB2016/images/{}".format(labels.image_name[image_num]))

# Size and label
print("Shape for image {}: {}".format(image_num, data.shape))
print("Percentage of pixeles with food: {:.2f}%".format(labels.food_pixels[image_num]))

# Plot image
plt.figure(figsize=(12,6))
imshow(data)
plt.show()
# Out:
# Shape for image 10: (480, 640, 3)
# Percentage of pixeles with food: 16.17%

# %% [markdown]
# En este momento, vamos a proceder a dividir el dataset en 3 conjuntos. Uno de ellos será el dataset de entrenamiento, el cual contendrá el 70% de los registros. Otro el que usaremos para llevar a cabo la validación, y pesará el 15% de los registros. Y por último, el conjunto de test estará formado por el 15% restante.
#
# Para mantener la reproducibilidad de los datos también vamos a definir una semilla.

# %%
# Split dataset into: train, validation and test
seed = 0
train_data, test_data = train_test_split(labels, test_size=0.3, random_state=seed)
dev_data, test_data = train_test_split(test_data, test_size=0.5, random_state=seed)

# Update index
train_data = train_data.reset_index(drop=True)
dev_data = dev_data.reset_index(drop=True)
test_data = test_data.reset_index(drop=True)

print("Train data shape: {}".format(train_data.shape))
print("Validation data shape: {}".format(dev_data.shape))
print("Test data shape: {}".format(test_data.shape))
# Out:
# Train data shape: (718, 2)
# Validation data shape: (154, 2)
# Test data shape: (155, 2)

# %% [markdown]
# Ahora sería el turno de cargar las imágenes, sin embargo como no solo vamos a realizar un modelo, probaremos diferentes configuraciones adecuadas a cada red que implementemos.
#
# La funcion definida en Keras encargada de realizar la generación de las imágenes es ImagedataGenerator, a la que siempre impondremos que reescale las imágenes en el intervalo [0,1] y en alguna ocasión, incluiremos otros parámetros adicionales que nos permitirán realizar *Data Augmentation*.

# %% [markdown]
# # 4.Creación del modelo

# %% [markdown]
# ## 4.1.Arquitectura ad-hoc

# %% [markdown]
# La primera red convolucional la diseñaremos nosotros mismos. Sin embargo, antes de comenzar a implementar el modelo debemos llevar a cabo la preparación de las imágenes.
#
# Para este primer caso, vamos a cargar las imágenes con el tamaño que vienen por defecto y usando un batch de 1 imagen. Ademas, a la hora de llamar la función *flow_from_dataframe()* vamos a decirle que no hay un número determinado de clases utilizando el párametro *class_mode='other'*.

# %%
# Rescale the images
datagen = ImageDataGenerator(rescale=1./255)

# Main parameters for loading the images
img_width = 640
img_height = 480
x_col = 'image_name'
y_col = 'food_pixels'

#  Generating batches for every partition
batch_size = 1
train_generator = datagen.flow_from_dataframe(dataframe=train_data, 
                                              directory=imgs_path, 
                                              x_col=x_col, 
                                              y_col=y_col, 
                                              has_ext=True,
                                              class_mode="other", 
                                              target_size=(img_width, img_height), 
                                              batch_size=batch_size)

dev_generator = datagen.flow_from_dataframe(dataframe=dev_data, 
                                              directory=imgs_path, 
                                              x_col=x_col, 
                                              y_col=y_col, 
                                              has_ext=True,
                                              class_mode="other", 
                                              target_size=(img_width, img_height), 
                                              batch_size=batch_size)

test_generator = datagen.flow_from_dataframe(dataframe=test_data, 
                                              directory=imgs_path, 
                                              x_col=x_col, 
                                              y_col=y_col, 
                                              has_ext=True,
                                              class_mode="other", 
                                              target_size=(img_width, img_height), 
                                              batch_size=batch_size)
# Out:
# Found 718 validated image filenames.
# Found 154 validated image filenames.
# Found 155 validated image filenames.

# %% [markdown]
# Definiremos el modelo llamando a la función Sequential() e iremos añadiendole diferentes capas.
#
# En nuestro caso, vamos a añadir cuatro bloques formados por una capa convolucional, seguida de una ReLU y finalmente una MaxPooling.
# Las capas convolucionales las iremos haciendo cada vez con más filtros para ir aumentando el volumen de activación. En cuando a las pooling, impondremos que el filtro sea de 3x3, para que se reduzca la imágen en no demasiadas capas.
#
# Posteriormente aplanaremos el volumen en un vector aplicando la capa Flatten.
#
# Para terminar, incluirimos dos capas completamente conectadas. La primera de ellas con 128 neuronas y la ultima, la salida, con una sola. Entre estas dos capas incluiremos un factor de regularización mediante una capa Dropout con un ratio del 50%.

# %%
# Initialize the model
model = Sequential()

# Add four block of layers (convolutional-relu-pooling)
model.add(Conv2D(32, 3, activation='relu', input_shape=(img_width,img_height,3)))
model.add(MaxPooling2D(3))

model.add(Conv2D(64, 3, activation='relu'))
model.add(MaxPooling2D(3))

model.add(Conv2D(128, 3, activation='relu'))
model.add(MaxPooling2D(3))

model.add(Conv2D(256, 3, activation='relu'))
model.add(MaxPooling2D(3))

# Add flatten layer to convert the volume into array
model.add(Flatten())

# Add two fully connected layers and a regularization dropout
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(rate = 0.5))
model.add(Dense(1, activation='relu'))

# Plot model
model.name = 'Model ad-hoc'
model.summary()
# Out:
# Model: "Model ad-hoc"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 638, 478, 32)      896
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 212, 159, 32)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 210, 157, 64)      18496
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 70, 52, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 68, 50, 128)       73856
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 22, 16, 128)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 20, 14, 256)       295168
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 6, 4, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6144)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               786560
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 1,175,105
# Trainable params: 1,175,105
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Una vez definida la arquitectura de la red, debemos compilarla. Tal y como se indica en el enunciado del ejercicio, la métrica que deberemos usar para poder comparar nuestros resultados con el baseline es el RMSE (Definido en el punto 2). Acorde con esta métrica, la función de pérdida que vamos a utilizar es el MSE, que solo se diferencia de la métrica usada en una raíz cuadrada. El otro parámetro que vamos a definir es el optimizador a usar, en este caso Adam con un *learning rate* de $10^{-4}$.
#
# Por otro lado, vamos a generar 100 epochs, es decir, la red recorrerá 100 veces el conjunto de entrenamiento. Asimismo, imponemos que el tamaño del batch sea 1, con lo que los pesos se reajustarán 100$\cdot$ 718= 71800$ veces durante la fase de entrenamiento.

# %%
# Compiling
model.compile(loss='mean_squared_error',
              optimizer=optimizers.adam(lr=1e-5),
              metrics=[root_mean_squared_error])

# Training the model
batch_size = 1
start = datetime.now()
history = model.fit_generator(train_generator,
                    epochs=100,
                    verbose=2,
                    steps_per_epoch=len(train_data)/batch_size,
                    validation_data=dev_generator,
                    validation_steps=len(dev_data)/batch_size)
print("Time spent: {}".format(datetime.now()-start))
# Out:
# Epoch 1/100
#  - 10s - loss: 65.9078 - root_mean_squared_error: 6.2307 - val_loss: 31.5002 - val_root_mean_squared_error: 4.7640
# Epoch 2/100
#  - 10s - loss: 28.6093 - root_mean_squared_error: 4.1589 - val_loss: 31.5194 - val_root_mean_squared_error: 4.7530
# Epoch 3/100
#  - 9s - loss: 29.2244 - root_mean_squared_error: 4.2895 - val_loss: 31.0079 - val_root_mean_squared_error: 4.7253
# Epoch 4/100
#  - 9s - loss: 28.1948 - root_mean_squared_error: 4.2728 - val_loss: 30.6224 - val_root_mean_squared_error: 4.6951
# Epoch 5/100
#  - 9s - loss: 28.4173 - root_mean_squared_error: 4.2855 - val_loss: 30.7540 - val_root_mean_squared_error: 4.6815
# Epoch 6/100
#  - 9s - loss: 27.5475 - root_mean_squared_error: 4.1363 - val_loss: 29.1411 - val_root_mean_squared_error: 4.5903
# Epoch 7/100
#  - 10s - loss: 26.7730 - root_mean_squared_error: 4.0961 - val_loss: 28.2403 - val_root_mean_squared_error: 4.5261
# Epoch 8/100
#  - 9s - loss: 26.1990 - root_mean_squared_error: 4.0994 - val_loss: 27.7678 - val_root_mean_squared_error: 4.4623
# Epoch 9/100
#  - 9s - loss: 25.5127 - root_mean_squared_error: 4.0536 - val_loss: 26.5122 - val_root_mean_squared_error: 4.3482
# Epoch 10/100
#  - 9s - loss: 25.4497 - root_mean_squared_error: 4.0078 - val_loss: 24.7005 - val_root_mean_squared_error: 4.1954
# Epoch 11/100
#  - 9s - loss: 23.2128 - root_mean_squared_error: 3.8619 - val_loss: 22.2016 - val_root_mean_squared_error: 3.9887
# Epoch 12/100
#  - 9s - loss: 20.7307 - root_mean_squared_error: 3.5864 - val_loss: 20.2549 - val_root_mean_squared_error: 3.7807
# Epoch 13/100
#  - 9s - loss: 20.6509 - root_mean_squared_error: 3.5834 - val_loss: 18.8301 - val_root_mean_squared_error: 3.6068
# Epoch 14/100
#  - 9s - loss: 19.1108 - root_mean_squared_error: 3.4746 - val_loss: 17.9040 - val_root_mean_squared_error: 3.4851
# Epoch 15/100
#  - 9s - loss: 18.4451 - root_mean_squared_error: 3.3395 - val_loss: 16.8862 - val_root_mean_squared_error: 3.3507
# Epoch 16/100
#  - 9s - loss: 18.3967 - root_mean_squared_error: 3.4028 - val_loss: 16.1460 - val_root_mean_squared_error: 3.2695
# Epoch 17/100
#  - 9s - loss: 17.5334 - root_mean_squared_error: 3.3008 - val_loss: 15.5504 - val_root_mean_squared_error: 3.1748
# Epoch 18/100
#  - 9s - loss: 18.0127 - root_mean_squared_error: 3.2949 - val_loss: 18.6457 - val_root_mean_squared_error: 3.4004
# Epoch 19/100
#  - 10s - loss: 17.0189 - root_mean_squared_error: 3.1846 - val_loss: 15.4072 - val_root_mean_squared_error: 3.1118
# Epoch 20/100
#  - 9s - loss: 16.5909 - root_mean_squared_error: 3.1718 - val_loss: 14.9575 - val_root_mean_squared_error: 3.0604
# Epoch 21/100
#  - 10s - loss: 16.4264 - root_mean_squared_error: 3.1733 - val_loss: 15.4040 - val_root_mean_squared_error: 3.0860
# Epoch 22/100
#  - 9s - loss: 16.5818 - root_mean_squared_error: 3.1646 - val_loss: 15.8886 - val_root_mean_squared_error: 3.1210
# Epoch 23/100
#  - 10s - loss: 16.5865 - root_mean_squared_error: 3.1654 - val_loss: 14.6475 - val_root_mean_squared_error: 2.9943
# Epoch 24/100
#  - 9s - loss: 14.9653 - root_mean_squared_error: 3.0113 - val_loss: 13.7732 - val_root_mean_squared_error: 2.9019
# Epoch 25/100
#  - 9s - loss: 15.5663 - root_mean_squared_error: 3.0515 - val_loss: 13.4925 - val_root_mean_squared_error: 2.8702
# Epoch 26/100
#  - 9s - loss: 15.4967 - root_mean_squared_error: 3.0483 - val_loss: 13.2737 - val_root_mean_squared_error: 2.8359
# Epoch 27/100
#  - 10s - loss: 15.7960 - root_mean_squared_error: 3.0932 - val_loss: 13.1792 - val_root_mean_squared_error: 2.8286
# Epoch 28/100
#  - 9s - loss: 16.2022 - root_mean_squared_error: 3.1253 - val_loss: 14.0560 - val_root_mean_squared_error: 2.8972
# Epoch 29/100
#  - 9s - loss: 14.3344 - root_mean_squared_error: 2.9519 - val_loss: 13.5526 - val_root_mean_squared_error: 2.8326
# Epoch 30/100
#  - 9s - loss: 15.5585 - root_mean_squared_error: 3.0218 - val_loss: 12.3792 - val_root_mean_squared_error: 2.7027
# Epoch 31/100
#  - 9s - loss: 14.7014 - root_mean_squared_error: 2.9406 - val_loss: 13.1458 - val_root_mean_squared_error: 2.7919
# Epoch 32/100
#  - 9s - loss: 14.4430 - root_mean_squared_error: 2.8646 - val_loss: 12.4325 - val_root_mean_squared_error: 2.7023
# Epoch 33/100
#  - 10s - loss: 14.3720 - root_mean_squared_error: 2.9479 - val_loss: 12.1030 - val_root_mean_squared_error: 2.6559
# Epoch 34/100
#  - 10s - loss: 14.4153 - root_mean_squared_error: 2.9632 - val_loss: 11.9542 - val_root_mean_squared_error: 2.6500
# Epoch 35/100
#  - 9s - loss: 15.3708 - root_mean_squared_error: 3.0333 - val_loss: 12.9403 - val_root_mean_squared_error: 2.7509
# Epoch 36/100
#  - 9s - loss: 13.7167 - root_mean_squared_error: 2.8844 - val_loss: 12.2172 - val_root_mean_squared_error: 2.6678
# Epoch 37/100
#  - 9s - loss: 14.3546 - root_mean_squared_error: 2.8954 - val_loss: 11.2548 - val_root_mean_squared_error: 2.5490
# Epoch 38/100
#  - 9s - loss: 15.5454 - root_mean_squared_error: 2.9665 - val_loss: 11.0707 - val_root_mean_squared_error: 2.5212
# Epoch 39/100
#  - 9s - loss: 14.8719 - root_mean_squared_error: 2.9353 - val_loss: 11.1795 - val_root_mean_squared_error: 2.5321
# Epoch 40/100
#  - 9s - loss: 14.4901 - root_mean_squared_error: 2.9023 - val_loss: 10.9988 - val_root_mean_squared_error: 2.5091
# Epoch 41/100
#  - 9s - loss: 13.2759 - root_mean_squared_error: 2.8024 - val_loss: 10.4711 - val_root_mean_squared_error: 2.4367
# Epoch 42/100
#  - 9s - loss: 14.3047 - root_mean_squared_error: 2.9156 - val_loss: 11.4003 - val_root_mean_squared_error: 2.5524
# Epoch 43/100
#  - 9s - loss: 12.8445 - root_mean_squared_error: 2.7746 - val_loss: 10.5542 - val_root_mean_squared_error: 2.4468
# Epoch 44/100
#  - 9s - loss: 13.9815 - root_mean_squared_error: 2.8865 - val_loss: 10.5818 - val_root_mean_squared_error: 2.4523
# Epoch 45/100
#  - 9s - loss: 13.2578 - root_mean_squared_error: 2.8070 - val_loss: 9.9265 - val_root_mean_squared_error: 2.3594
# Epoch 46/100
#  - 9s - loss: 12.8515 - root_mean_squared_error: 2.7528 - val_loss: 9.3939 - val_root_mean_squared_error: 2.2618
# Epoch 47/100
#  - 9s - loss: 13.0447 - root_mean_squared_error: 2.7839 - val_loss: 9.2727 - val_root_mean_squared_error: 2.2476
# Epoch 48/100
#  - 9s - loss: 13.0675 - root_mean_squared_error: 2.7860 - val_loss: 9.0512 - val_root_mean_squared_error: 2.2149
# Epoch 49/100
#  - 9s - loss: 13.2260 - root_mean_squared_error: 2.7601 - val_loss: 9.3559 - val_root_mean_squared_error: 2.2631
# Epoch 50/100
#  - 9s - loss: 12.0253 - root_mean_squared_error: 2.6705 - val_loss: 9.2775 - val_root_mean_squared_error: 2.2562
# Epoch 51/100
#  - 9s - loss: 12.4902 - root_mean_squared_error: 2.7189 - val_loss: 9.2118 - val_root_mean_squared_error: 2.2539
# Epoch 52/100
#  - 9s - loss: 12.2352 - root_mean_squared_error: 2.6825 - val_loss: 9.2883 - val_root_mean_squared_error: 2.2680
# Epoch 53/100
#  - 9s - loss: 11.6302 - root_mean_squared_error: 2.6097 - val_loss: 8.9625 - val_root_mean_squared_error: 2.2188
# Epoch 54/100
#  - 9s - loss: 12.5514 - root_mean_squared_error: 2.7112 - val_loss: 8.7754 - val_root_mean_squared_error: 2.1959
# Epoch 55/100
#  - 10s - loss: 11.6717 - root_mean_squared_error: 2.6555 - val_loss: 8.1343 - val_root_mean_squared_error: 2.0768
# Epoch 56/100
#  - 10s - loss: 12.6026 - root_mean_squared_error: 2.7365 - val_loss: 8.3804 - val_root_mean_squared_error: 2.1428
# Epoch 57/100
#  - 9s - loss: 11.7602 - root_mean_squared_error: 2.6710 - val_loss: 7.9217 - val_root_mean_squared_error: 2.0062
# Epoch 58/100
#  - 9s - loss: 11.1467 - root_mean_squared_error: 2.5853 - val_loss: 7.8576 - val_root_mean_squared_error: 2.0531
# Epoch 59/100
#  - 10s - loss: 11.3759 - root_mean_squared_error: 2.5984 - val_loss: 8.3391 - val_root_mean_squared_error: 2.1423
# Epoch 60/100
#  - 9s - loss: 11.3085 - root_mean_squared_error: 2.5701 - val_loss: 9.0179 - val_root_mean_squared_error: 2.2584
# Epoch 61/100
#  - 9s - loss: 10.1900 - root_mean_squared_error: 2.4641 - val_loss: 8.3786 - val_root_mean_squared_error: 2.1465
# Epoch 62/100
#  - 9s - loss: 10.7112 - root_mean_squared_error: 2.5372 - val_loss: 8.3625 - val_root_mean_squared_error: 2.1519
# Epoch 63/100
#  - 10s - loss: 10.9948 - root_mean_squared_error: 2.5500 - val_loss: 10.5040 - val_root_mean_squared_error: 2.5256
# Epoch 64/100
#  - 10s - loss: 10.3619 - root_mean_squared_error: 2.4809 - val_loss: 7.1763 - val_root_mean_squared_error: 1.9255
# Epoch 65/100
#  - 10s - loss: 11.1298 - root_mean_squared_error: 2.6132 - val_loss: 8.4147 - val_root_mean_squared_error: 2.1748
# Epoch 66/100
#  - 10s - loss: 10.8128 - root_mean_squared_error: 2.5886 - val_loss: 9.5367 - val_root_mean_squared_error: 2.3712
# Epoch 67/100
#  - 10s - loss: 9.3065 - root_mean_squared_error: 2.3588 - val_loss: 6.9067 - val_root_mean_squared_error: 1.8702
# Epoch 68/100
#  - 10s - loss: 9.8738 - root_mean_squared_error: 2.4360 - val_loss: 7.3297 - val_root_mean_squared_error: 1.9772
# Epoch 69/100
#  - 10s - loss: 11.2883 - root_mean_squared_error: 2.5640 - val_loss: 6.7952 - val_root_mean_squared_error: 1.8742
# Epoch 70/100
#  - 10s - loss: 10.5340 - root_mean_squared_error: 2.5042 - val_loss: 6.8602 - val_root_mean_squared_error: 1.8619
# Epoch 71/100
#  - 10s - loss: 9.8725 - root_mean_squared_error: 2.3609 - val_loss: 7.6781 - val_root_mean_squared_error: 2.0424
# Epoch 72/100
#  - 10s - loss: 11.0973 - root_mean_squared_error: 2.5543 - val_loss: 7.9670 - val_root_mean_squared_error: 2.0879
# Epoch 73/100
#  - 10s - loss: 9.4674 - root_mean_squared_error: 2.3717 - val_loss: 7.1584 - val_root_mean_squared_error: 1.9626
# Epoch 74/100
#  - 10s - loss: 9.9355 - root_mean_squared_error: 2.5087 - val_loss: 9.7682 - val_root_mean_squared_error: 2.3987
# Epoch 75/100
#  - 10s - loss: 9.8666 - root_mean_squared_error: 2.4002 - val_loss: 6.6624 - val_root_mean_squared_error: 1.8495
# Epoch 76/100
#  - 10s - loss: 10.5326 - root_mean_squared_error: 2.4305 - val_loss: 8.5867 - val_root_mean_squared_error: 2.2242
# Epoch 77/100
#  - 10s - loss: 9.6091 - root_mean_squared_error: 2.3666 - val_loss: 7.2998 - val_root_mean_squared_error: 1.9813
# Epoch 78/100
#  - 10s - loss: 9.5380 - root_mean_squared_error: 2.3892 - val_loss: 7.5646 - val_root_mean_squared_error: 2.0408
# Epoch 79/100
#  - 10s - loss: 10.5101 - root_mean_squared_error: 2.5100 - val_loss: 6.4220 - val_root_mean_squared_error: 1.8114
# Epoch 80/100
#  - 10s - loss: 9.6364 - root_mean_squared_error: 2.3447 - val_loss: 6.4761 - val_root_mean_squared_error: 1.8035
# Epoch 81/100
#  - 10s - loss: 9.0474 - root_mean_squared_error: 2.3057 - val_loss: 6.4398 - val_root_mean_squared_error: 1.8004
# Epoch 82/100
#  - 10s - loss: 9.3263 - root_mean_squared_error: 2.3708 - val_loss: 6.4197 - val_root_mean_squared_error: 1.7910
# Epoch 83/100
#  - 10s - loss: 9.0135 - root_mean_squared_error: 2.3162 - val_loss: 6.2726 - val_root_mean_squared_error: 1.7575
# Epoch 84/100
#  - 10s - loss: 9.1864 - root_mean_squared_error: 2.3424 - val_loss: 6.3836 - val_root_mean_squared_error: 1.7924
# Epoch 85/100
#  - 10s - loss: 8.6527 - root_mean_squared_error: 2.2607 - val_loss: 6.4280 - val_root_mean_squared_error: 1.8124
# Epoch 86/100
#  - 10s - loss: 9.1700 - root_mean_squared_error: 2.3195 - val_loss: 6.2859 - val_root_mean_squared_error: 1.7763
# Epoch 87/100
#  - 10s - loss: 9.0031 - root_mean_squared_error: 2.2950 - val_loss: 8.0909 - val_root_mean_squared_error: 2.1513
# Epoch 88/100
#  - 10s - loss: 9.0625 - root_mean_squared_error: 2.3099 - val_loss: 6.1998 - val_root_mean_squared_error: 1.7658
# Epoch 89/100
#  - 10s - loss: 9.8685 - root_mean_squared_error: 2.4407 - val_loss: 9.2711 - val_root_mean_squared_error: 2.3632
# Epoch 90/100
#  - 10s - loss: 8.8512 - root_mean_squared_error: 2.2714 - val_loss: 6.9778 - val_root_mean_squared_error: 1.9329
# Epoch 91/100
#  - 10s - loss: 9.0828 - root_mean_squared_error: 2.3395 - val_loss: 7.1112 - val_root_mean_squared_error: 1.9851
# Epoch 92/100
#  - 10s - loss: 8.5861 - root_mean_squared_error: 2.2722 - val_loss: 7.4740 - val_root_mean_squared_error: 2.0479
# Epoch 93/100
#  - 10s - loss: 8.1623 - root_mean_squared_error: 2.2004 - val_loss: 7.2454 - val_root_mean_squared_error: 1.9975
# Epoch 94/100
#  - 10s - loss: 8.2608 - root_mean_squared_error: 2.2209 - val_loss: 6.3708 - val_root_mean_squared_error: 1.8143
# Epoch 95/100
#  - 10s - loss: 8.3599 - root_mean_squared_error: 2.2445 - val_loss: 6.0859 - val_root_mean_squared_error: 1.7448
# Epoch 96/100
#  - 10s - loss: 8.8954 - root_mean_squared_error: 2.2809 - val_loss: 6.5332 - val_root_mean_squared_error: 1.8612
# Epoch 97/100
#  - 10s - loss: 9.2229 - root_mean_squared_error: 2.3084 - val_loss: 6.4413 - val_root_mean_squared_error: 1.8599
# Epoch 98/100
#  - 10s - loss: 8.6256 - root_mean_squared_error: 2.2032 - val_loss: 6.4151 - val_root_mean_squared_error: 1.8396
# Epoch 99/100
#  - 10s - loss: 8.1876 - root_mean_squared_error: 2.2093 - val_loss: 6.3622 - val_root_mean_squared_error: 1.8320
# Epoch 100/100
#  - 10s - loss: 8.6399 - root_mean_squared_error: 2.2632 - val_loss: 5.7880 - val_root_mean_squared_error: 1.7085
# Time spent: 0:15:59.417087

# %% [markdown]
# Grafiquemos cual ha sido el error de entrenamiendo y validación en función de las epocas.

# %%
plot_history(history)

# %% [markdown]
# Veamos ahora que error comete el model ante nuevas imágenes nunca vistas.

# %%
# Evaluating the model
test_loss, test_rmse = model.evaluate_generator(test_generator,
                                               steps=len(test_data)/batch_size,
                                               verbose=1)
print("test_loss: %.4f, test_rmse: %.4f" % (test_loss, test_rmse))
# Out:
# 155/155 [==============================] - 2s 11ms/step
# test_loss: 4.0023, test_rmse: 1.5979

# %% [markdown]
# Parece que nuestro modelo es capaz de superar el baseline que habiamos impuesto. Sin embargo el tiempo que necesitamos para realizar el entrenamiento es

# %% [markdown]
# ## 4.2.Transfering learning VGG16

# %% [markdown]
# El segundo modelo que vamos a probar, no va a ser uno que diseñemos nosotros mismos, si no una red preentrenada con el conjunto de datos ImageNet. A la hora de hacer transfer learning podemos optar por dos opciones: por un lado usar una red preentrenada como extractor de características y modificar las últimas capas(fully-connected) para ajustarlas a nuestro problema, o bien, usar la red completa y hacer fine-tuning de los pesos.
# Teniendo en cuenta que el conjunto de datos de ImageNet contiene más de 1 millon de imágenes, y nuestro problema únicamente 1000, vamos a optar por la primera opción, ya que si no podríamos cometer sobreajuste.
#
# La red en cuestión que probaremos será VGG16. Si vamos a la documentación de Keras podemos ver que, a pesar de poder recibir imagenes del tamaño que sea, fue entrenada recibiendo como input imagenes de tamañao 224x224. Por esta razón, vamos a implementar de nuevo ImageDataGenerator con el que, a la hora de generar los conjuntos de entrenamiento, validación y test impongamos que el tamaño de salida de las imagenes sea 224x224.

# %%
datagen = ImageDataGenerator(rescale=1./255)

# Resize the images: 224x224
img_width = 224
img_height = 224
x_col = 'image_name'
y_col = 'food_pixels'

batch_size = 16
train_generator = datagen.flow_from_dataframe(dataframe=train_data, 
                                              directory=imgs_path, 
                                              x_col=x_col, 
                                              y_col=y_col, 
                                              has_ext=True,
                                              class_mode="other", 
                                              target_size=(img_width, img_height), 
                                              batch_size=batch_size)

dev_generator = datagen.flow_from_dataframe(dataframe=dev_data, 
                                              directory=imgs_path, 
                                              x_col=x_col, 
                                              y_col=y_col, 
                                              has_ext=True,
                                              class_mode="other", 
                                              target_size=(img_width, img_height), 
                                              batch_size=batch_size)

test_generator = datagen.flow_from_dataframe(dataframe=test_data, 
                                              directory=imgs_path, 
                                              x_col=x_col, 
                                              y_col=y_col, 
                                              has_ext=True,
                                              class_mode="other", 
                                              target_size=(img_width, img_height), 
                                              batch_size=batch_size)
# Out:
# Found 718 validated image filenames.
# Found 154 validated image filenames.
# Found 155 validated image filenames.

# %% [markdown]
# Una vez tenemos las imagenes, debemos a cargar la red desde la que haremos transfer learning. Como se ha dicho, imponemos que los pesos sean ajustados con el dataset ImageNet, que la red no nos incluya las capas completamente conectadas de la parte final de la red y definimos el tamaño de las imagenes de entrada.
#
# En este caso, el volumen de activación de la última capa de VGG16 posee una profundidad de 512, por tanto, la primera capa que vamos a añadir a la red es una capa llamada 'GlobalAveragePooling2D' para condensar el volumen de activación en un array con 512 dimensiones.
#
# Adicionalmente, vamos a incluir al final de la red tres capas completamente conectadas con 512, 256 y 64 neuronas respectivamente. Para evitar el sobreajuste, vamos a incluir una capa Dropout con un ratio del 50%.
#
# Finalmente, añadimos una última capa con una única neurnona, ya que estamos en un problema que solo necesita un número como salida. Como además necesitamos que el output sea estríctamente positivo, incluiremos una función de activación ReLU.

# %%
# Load pre-training VGG16 model
base_model = applications.vgg16.VGG16(weights='imagenet', 
                                      include_top=False, 
                                      input_shape=(img_width,img_height,3))


for layer in base_model.layers:
    layer.trainable = False


model = Sequential(layers=[
                           base_model,
                           GlobalAveragePooling2D(),
                           Dense(512, activation='relu'),
                           Dense(256, activation='relu'),
                           Dropout(rate = 0.5),
                           Dense(64, activation='relu'),
                           Dense(1, activation='relu')
                           ])  
model.name = 'Transfer learning - VGG16'          
model.summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# Model: "Transfer learning - VGG16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg16 (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 15,125,185
# Trainable params: 410,497
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# Como podemos ver, la estructura de nuestro modelo es la red VGG16, más las últimas capas que hemos impuesto nostros mismos. Destacar como el transfer learning nos aporta que, a pesar de haber más de 15 millones de parámetros, nuestra máquina solo tendrá que ajustar entorno a 400.000.
#
# Para compilar el modelo, de nuevo usamos MSE como función de pérdida y RMSE como la metrica. Optimizaremos el modelo usando Adam y el learning rate que nos ha dado buenos resultados para este modelo, $10^{-4}$.

# %%
# Complile the model
model.compile(loss='mean_squared_error',
              optimizer=optimizers.adam(lr=1e-4),
              metrics=[root_mean_squared_error])

# %% [markdown]
# Llegado este punto, toca entrenar el modelo igual que hicimos antes, pero en este caso solo serán necesarios 30 epochs.

# %%
# Train the model
start = datetime.now()
batch_size = 16
history = model.fit_generator(train_generator,
                    epochs=30,
                    verbose=2, #verbose=0,
                    steps_per_epoch=len(train_data)/batch_size,
                    validation_data=dev_generator,
                    validation_steps=len(dev_data)/batch_size)

print("Time spent: {}".format(datetime.now()-start))
# Out:
# Epoch 1/30
#  - 7s - loss: 150.1517 - root_mean_squared_error: 12.0445 - val_loss: 69.7680 - val_root_mean_squared_error: 8.2785
# Epoch 2/30
#  - 5s - loss: 32.4034 - root_mean_squared_error: 5.5174 - val_loss: 28.3420 - val_root_mean_squared_error: 5.2749
# Epoch 3/30
#  - 6s - loss: 24.3817 - root_mean_squared_error: 4.8481 - val_loss: 26.0959 - val_root_mean_squared_error: 5.0684
# Epoch 4/30
#  - 6s - loss: 24.8529 - root_mean_squared_error: 4.9016 - val_loss: 24.2408 - val_root_mean_squared_error: 4.8655
# Epoch 5/30
#  - 6s - loss: 22.5873 - root_mean_squared_error: 4.6330 - val_loss: 22.3361 - val_root_mean_squared_error: 4.6864
# Epoch 6/30
#  - 6s - loss: 18.5009 - root_mean_squared_error: 4.2155 - val_loss: 20.3583 - val_root_mean_squared_error: 4.4696
# Epoch 7/30
#  - 6s - loss: 18.7272 - root_mean_squared_error: 4.2415 - val_loss: 18.2818 - val_root_mean_squared_error: 4.2497
# Epoch 8/30
#  - 6s - loss: 16.6930 - root_mean_squared_error: 4.0325 - val_loss: 16.2485 - val_root_mean_squared_error: 3.9927
# Epoch 9/30
#  - 6s - loss: 14.3429 - root_mean_squared_error: 3.7099 - val_loss: 14.2286 - val_root_mean_squared_error: 3.7306
# Epoch 10/30
#  - 6s - loss: 13.5939 - root_mean_squared_error: 3.6055 - val_loss: 12.6069 - val_root_mean_squared_error: 3.5114
# Epoch 11/30
#  - 6s - loss: 12.6318 - root_mean_squared_error: 3.5073 - val_loss: 11.3020 - val_root_mean_squared_error: 3.3289
# Epoch 12/30
#  - 6s - loss: 12.7006 - root_mean_squared_error: 3.5006 - val_loss: 10.4083 - val_root_mean_squared_error: 3.1805
# Epoch 13/30
#  - 6s - loss: 11.6658 - root_mean_squared_error: 3.3571 - val_loss: 10.0198 - val_root_mean_squared_error: 3.1156
# Epoch 14/30
#  - 6s - loss: 10.5371 - root_mean_squared_error: 3.1928 - val_loss: 9.5183 - val_root_mean_squared_error: 3.0350
# Epoch 15/30
#  - 6s - loss: 11.6175 - root_mean_squared_error: 3.3169 - val_loss: 8.5457 - val_root_mean_squared_error: 2.9026
# Epoch 16/30
#  - 6s - loss: 10.7217 - root_mean_squared_error: 3.2021 - val_loss: 8.0615 - val_root_mean_squared_error: 2.8148
# Epoch 17/30
#  - 6s - loss: 10.4443 - root_mean_squared_error: 3.1541 - val_loss: 7.8902 - val_root_mean_squared_error: 2.7759
# Epoch 18/30
#  - 6s - loss: 9.4174 - root_mean_squared_error: 3.0143 - val_loss: 7.4650 - val_root_mean_squared_error: 2.7106
# Epoch 19/30
#  - 6s - loss: 9.3257 - root_mean_squared_error: 3.0111 - val_loss: 7.4439 - val_root_mean_squared_error: 2.7029
# Epoch 20/30
#  - 6s - loss: 9.1415 - root_mean_squared_error: 2.9495 - val_loss: 7.4813 - val_root_mean_squared_error: 2.6949
# Epoch 21/30
#  - 6s - loss: 8.7793 - root_mean_squared_error: 2.9174 - val_loss: 7.2140 - val_root_mean_squared_error: 2.6780
# Epoch 22/30
#  - 6s - loss: 8.8401 - root_mean_squared_error: 2.9218 - val_loss: 7.6381 - val_root_mean_squared_error: 2.7432
# Epoch 23/30
#  - 6s - loss: 8.9398 - root_mean_squared_error: 2.9166 - val_loss: 6.9784 - val_root_mean_squared_error: 2.5965
# Epoch 24/30
#  - 6s - loss: 8.2425 - root_mean_squared_error: 2.8176 - val_loss: 6.5702 - val_root_mean_squared_error: 2.5227
# Epoch 25/30
#  - 6s - loss: 8.5049 - root_mean_squared_error: 2.8763 - val_loss: 6.7189 - val_root_mean_squared_error: 2.5417
# Epoch 26/30
#  - 6s - loss: 8.4161 - root_mean_squared_error: 2.8503 - val_loss: 6.3456 - val_root_mean_squared_error: 2.4749
# Epoch 27/30
#  - 6s - loss: 8.8864 - root_mean_squared_error: 2.9110 - val_loss: 6.2901 - val_root_mean_squared_error: 2.4704
# Epoch 28/30
#  - 6s - loss: 7.8148 - root_mean_squared_error: 2.7365 - val_loss: 6.2776 - val_root_mean_squared_error: 2.4580
# Epoch 29/30
#  - 6s - loss: 8.2046 - root_mean_squared_error: 2.8143 - val_loss: 6.4319 - val_root_mean_squared_error: 2.5046
# Epoch 30/30
#  - 6s - loss: 7.5804 - root_mean_squared_error: 2.7071 - val_loss: 6.0089 - val_root_mean_squared_error: 2.4136
# Time spent: 0:02:51.378077

# %%
plot_history(history)

# %% [markdown]
# Finalmente, validamos el modelo con el conjunto de test.

# %%
# Por ultimo, podemos evaluar el modelo en el conjunto de test
test_loss, test_rmse = model.evaluate_generator(test_generator,
                                               steps=len(test_data)/batch_size,
                                               verbose=1)
print("test_loss: %.4f, test_rmse: %.4f" % (test_loss, test_rmse))
# Out:
# 10/9 [==============================] - 2s 162ms/step
# test_loss: 4.8114, test_rmse: 2.1870

# %% [markdown]
# ## 4.3. Transfer learning VGG19

# %% [markdown]
# Para finalizar, vamos a probar una variante de VGG16 denominada VGG19. La diferencia entre uno y otro, es que VGG19 cuenta con 3 capas convolucionales más con respecto a VGG16, pero la idea principal de mantener el tamaño de las convoluciones pequeño y conseguir una red profunda, no cambia.
#
# Al modificar el tamaño de los batches, puede darse el caso de cometer sobre ajuste. Para evitar esto, vamos a hacer que el modelo no siempre vea las imagenes en la misma posición, las vamos a rotar aleatoriamente 90º. Además, vamos a realizar un *flip* horizontal.

# %%
datagen = ImageDataGenerator(rescale=1./255, 
                             horizontal_flip=True, 
                             rotation_range=90)

# Resize the images: 224x224
img_width = 224
img_height = 224
x_col = 'image_name'
y_col = 'food_pixels'

batch_size = 1
train_generator = datagen.flow_from_dataframe(dataframe=train_data, 
                                              directory=imgs_path, 
                                              x_col=x_col, 
                                              y_col=y_col, 
                                              has_ext=True,
                                              class_mode="other", 
                                              target_size=(img_width, img_height), 
                                              batch_size=batch_size)

dev_generator = datagen.flow_from_dataframe(dataframe=dev_data, 
                                              directory=imgs_path, 
                                              x_col=x_col, 
                                              y_col=y_col, 
                                              has_ext=True,
                                              class_mode="other", 
                                              target_size=(img_width, img_height), 
                                              batch_size=batch_size)

test_generator = datagen.flow_from_dataframe(dataframe=test_data, 
                                              directory=imgs_path, 
                                              x_col=x_col, 
                                              y_col=y_col, 
                                              has_ext=True,
                                              class_mode="other", 
                                              target_size=(img_width, img_height), 
                                              batch_size=batch_size)
# Out:
# Found 718 validated image filenames.
# Found 154 validated image filenames.
# Found 155 validated image filenames.

# %% [markdown]
# Definimos el modelo de nuevo

# %%
# Load pre-training VGG16 model
base_model = applications.vgg19.VGG19(weights='imagenet', 
                                      include_top=False, 
                                      input_shape=(img_width,img_height,3))


for layer in base_model.layers:
    layer.trainable = False


model = Sequential(layers=[
                           base_model,
                           GlobalAveragePooling2D(),
                           Dense(512, activation='relu'),
                           Dense(256, activation='relu'),
                           Dropout(rate = 0.5),
                           Dense(64, activation='relu'),
                           Dense(1, activation='relu')
                           ])  
model.name = 'Transfer learning - VGG19'          
model.summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# Model: "Transfer learning - VGG19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Model)                (None, 7, 7, 512)         20024384
# _________________________________________________________________
# global_average_pooling2d_5 ( (None, 512)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_24 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_25 (Dense)             (None, 64)                16448
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 20,434,881
# Trainable params: 410,497
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# Compilamos

# %%
# Complile the model
model.compile(loss='mean_squared_error',
              optimizer=optimizers.adam(lr=1e-4),
              metrics=[root_mean_squared_error])

# %% [markdown]
# Realizamos el entrenamiento

# %%
# Entrenamos el modelo con los datos preparados en el punto 2
start = datetime.now()
batch_size = 1
history = model.fit_generator(train_generator,
                    epochs=30,
                    verbose=2,
                    steps_per_epoch=len(train_data)/batch_size,
                    validation_data=dev_generator,
                    validation_steps=len(dev_data)/batch_size)

print("Time spent: {}".format(datetime.now()-start))
# Out:
# Epoch 1/30
#  - 18s - loss: 35.9485 - root_mean_squared_error: 4.7019 - val_loss: 21.0798 - val_root_mean_squared_error: 3.9044
# Epoch 2/30
#  - 17s - loss: 16.6434 - root_mean_squared_error: 3.1803 - val_loss: 13.9213 - val_root_mean_squared_error: 3.0923
# Epoch 3/30
#  - 17s - loss: 12.9783 - root_mean_squared_error: 2.7443 - val_loss: 15.3126 - val_root_mean_squared_error: 3.1839
# Epoch 4/30
#  - 17s - loss: 12.6071 - root_mean_squared_error: 2.7570 - val_loss: 9.9406 - val_root_mean_squared_error: 2.5699
# Epoch 5/30
#  - 17s - loss: 11.6691 - root_mean_squared_error: 2.6823 - val_loss: 9.5934 - val_root_mean_squared_error: 2.4356
# Epoch 6/30
#  - 17s - loss: 11.3210 - root_mean_squared_error: 2.5893 - val_loss: 10.7030 - val_root_mean_squared_error: 2.6086
# Epoch 7/30
#  - 16s - loss: 11.0672 - root_mean_squared_error: 2.5912 - val_loss: 8.5901 - val_root_mean_squared_error: 2.3372
# Epoch 8/30
#  - 16s - loss: 10.1426 - root_mean_squared_error: 2.5149 - val_loss: 8.6093 - val_root_mean_squared_error: 2.3205
# Epoch 9/30
#  - 16s - loss: 9.3813 - root_mean_squared_error: 2.3553 - val_loss: 7.5411 - val_root_mean_squared_error: 2.1795
# Epoch 10/30
#  - 17s - loss: 9.3318 - root_mean_squared_error: 2.3788 - val_loss: 7.9624 - val_root_mean_squared_error: 2.1714
# Epoch 11/30
#  - 17s - loss: 10.1486 - root_mean_squared_error: 2.4793 - val_loss: 9.8285 - val_root_mean_squared_error: 2.4995
# Epoch 12/30
#  - 17s - loss: 9.6234 - root_mean_squared_error: 2.4150 - val_loss: 9.0285 - val_root_mean_squared_error: 2.4256
# Epoch 13/30
#  - 17s - loss: 8.4305 - root_mean_squared_error: 2.2807 - val_loss: 9.2719 - val_root_mean_squared_error: 2.4646
# Epoch 14/30
#  - 17s - loss: 8.7401 - root_mean_squared_error: 2.2919 - val_loss: 7.0974 - val_root_mean_squared_error: 2.1098
# Epoch 15/30
#  - 17s - loss: 9.1779 - root_mean_squared_error: 2.3511 - val_loss: 7.3882 - val_root_mean_squared_error: 2.0843
# Epoch 16/30
#  - 17s - loss: 8.3753 - root_mean_squared_error: 2.2804 - val_loss: 5.8742 - val_root_mean_squared_error: 1.9361
# Epoch 17/30
#  - 17s - loss: 8.5794 - root_mean_squared_error: 2.2702 - val_loss: 6.5753 - val_root_mean_squared_error: 2.0535
# Epoch 18/30
#  - 17s - loss: 8.2672 - root_mean_squared_error: 2.2335 - val_loss: 6.1482 - val_root_mean_squared_error: 2.0495
# Epoch 19/30
#  - 17s - loss: 9.1116 - root_mean_squared_error: 2.3235 - val_loss: 6.9154 - val_root_mean_squared_error: 2.0561
# Epoch 20/30
#  - 17s - loss: 8.2498 - root_mean_squared_error: 2.2239 - val_loss: 9.0076 - val_root_mean_squared_error: 2.3848
# Epoch 21/30
#  - 17s - loss: 8.3801 - root_mean_squared_error: 2.2798 - val_loss: 7.7355 - val_root_mean_squared_error: 2.2334
# Epoch 22/30
#  - 17s - loss: 7.7081 - root_mean_squared_error: 2.1702 - val_loss: 11.8371 - val_root_mean_squared_error: 2.7660
# Epoch 23/30
#  - 17s - loss: 7.3490 - root_mean_squared_error: 2.1059 - val_loss: 6.5465 - val_root_mean_squared_error: 2.0052
# Epoch 24/30
#  - 17s - loss: 8.3001 - root_mean_squared_error: 2.2332 - val_loss: 6.1665 - val_root_mean_squared_error: 1.9396
# Epoch 25/30
#  - 17s - loss: 8.6725 - root_mean_squared_error: 2.2558 - val_loss: 7.3603 - val_root_mean_squared_error: 2.1458
# Epoch 26/30
#  - 17s - loss: 7.5575 - root_mean_squared_error: 2.1463 - val_loss: 6.0643 - val_root_mean_squared_error: 1.9244
# Epoch 27/30
#  - 17s - loss: 7.5970 - root_mean_squared_error: 2.1313 - val_loss: 7.6774 - val_root_mean_squared_error: 2.1725
# Epoch 28/30
#  - 17s - loss: 7.4081 - root_mean_squared_error: 2.1118 - val_loss: 7.2137 - val_root_mean_squared_error: 2.1497
# Epoch 29/30
#  - 17s - loss: 8.0668 - root_mean_squared_error: 2.2187 - val_loss: 5.6980 - val_root_mean_squared_error: 1.8773
# Epoch 30/30
#  - 17s - loss: 7.6510 - root_mean_squared_error: 2.1265 - val_loss: 5.6757 - val_root_mean_squared_error: 1.9226
# Time spent: 0:08:24.560771

# %%
plot_history(history)

# %%
# Por ultimo, podemos evaluar el modelo en el conjunto de test
print()
test_loss, test_rmse = model.evaluate_generator(test_generator,
                                               steps=len(test_data)/batch_size,
                                               verbose=1)
print("test_loss: %.4f, test_rmse: %.4f" % (test_loss, test_rmse))
# Out:
# 155/155 [==============================] - 3s 20ms/step
# test_loss: 5.1064, test_rmse: 1.7883
